# %%
from pathlib import Path
import os

# Load OpenAI API key from a local file (not committed to git)
key_path = Path(r"C:\Users\yehud\OneDrive\DataServices\DoubleRobust\API Keys\Business_Segment_V1.txt")
if not key_path.exists():
    raise FileNotFoundError(f"OpenAI key file not found: {key_path}")

os.environ["OPENAI_API_KEY"] = key_path.read_text(encoding="utf-8").strip()

# %%
import os
from pprint import pprint

# Required: SEC compliance user agent (must include your email)
os.environ.setdefault("SEC_USER_AGENT", "RevenueSegBot/0.1 (josh.dayan@gmail.com)")

# Required for ReAct pipeline
# IMPORTANT: do NOT hardcode API keys into notebooks/repos.
# Set OPENAI_API_KEY in your environment before running.
if not os.getenv("OPENAI_API_KEY"):
    raise RuntimeError(
        "OPENAI_API_KEY is not set. In PowerShell run: $env:OPENAI_API_KEY='...'; then restart the kernel."
    )

from revseg.pipeline import run_pipeline

tickers = ["AAPL", "MSFT", "GOOGL", "AMZN", "NVDA", "META", "AVGO", "TSLA", "JPM", "XOM"]

report = run_pipeline(
    tickers=tickers,
    model="gpt-4.1-mini",
    max_react_iters=3,
    out_dir="data/outputs",
)

# Compact summary
summary = {
    t: {
        "ok": r.get("ok"),
        "segment_year": r.get("segment_year"),
        "n_segments": r.get("n_segments"),
        "errors": r.get("errors"),
    }
    for t, r in report.get("tickers", {}).items()
}

pprint(summary)
print("\nWrote outputs under:", report.get("outputs_dir"))
# Out:
# c:\Users\yehud\Business Classification\revseg\table_candidates.py:385: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html, "lxml")
# c:\Users\yehud\Business Classification\revseg\react_agents.py:128: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html, "lxml")
# c:\Users\yehud\Business Classification\revseg\react_agents.py:101: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html, "lxml")
# [AAPL] selecting segment table (iter 1)...
# [AAPL] inferring layout for t0015 (iter 1)...
# c:\Users\yehud\Business Classification\revseg\table_candidates.py:482: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html, "lxml")
# [AAPL] extracting total revenue from income statement t0037...
# [AAPL] income statement total not found; falling back to SEC companyfacts...
# c:\Users\yehud\Business Classification\revseg\pipeline.py:77: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html, "lxml")
# [AAPL] summarizing segment descriptions (LLM)...
# [AAPL] expanding key items per segment (LLM)...
# [MSFT] selecting segment table (iter 1)...
# [MSFT] inferring layout for t0071 (iter 1)...
# [MSFT] extracting total revenue from income statement t0013...
# [MSFT] selecting segment table (iter 2)...
# [GOOGL] selecting segment table (iter 1)...
# [GOOGL] inferring layout for t0059 (iter 1)...
# [GOOGL] extracting total revenue from income statement t0046...
# [GOOGL] income statement total not found; falling back to SEC companyfacts...
# [GOOGL] summarizing segment descriptions (LLM)...
# [GOOGL] expanding key items per segment (LLM)...
# [GOOGL] selecting other revenue tables (LLM)...
# [AMZN] selecting segment table (iter 1)...
# [AMZN] inferring layout for t0024 (iter 1)...
# [AMZN] income statement total not found; falling back to SEC companyfacts...
# [AMZN] selecting segment table (iter 2)...
# [NVDA] selecting segment table (iter 1)...
# [NVDA] inferring layout for t0055 (iter 1)...
# [NVDA] extracting total revenue from income statement t0009...
# [NVDA] income statement total not found; falling back to SEC companyfacts...
# [NVDA] selecting segment table (iter 2)...
# [NVDA] inferring layout for t0055 (iter 2)...
# [NVDA] extracting total revenue from income statement t0009...
# [NVDA] income statement total not found; falling back to SEC companyfacts...
# [NVDA] selecting segment table (iter 3)...
# [NVDA] inferring layout for t0055 (iter 3)...
# [NVDA] extracting total revenue from income statement t0009...
# [NVDA] income statement total not found; falling back to SEC companyfacts...
# [META] selecting segment table (iter 1)...
# [META] inferring layout for t0031 (iter 1)...
# [META] extracting total revenue from income statement t0010...
# [META] income statement total not found; falling back to SEC companyfacts...
# [META] summarizing segment descriptions (LLM)...
# [META] expanding key items per segment (LLM)...
# [AVGO] selecting segment table (iter 1)...
# [AVGO] inferring layout for t0014 (iter 1)...
# [AVGO] extracting total revenue from income statement t0073...
# [AVGO] income statement total not found; falling back to SEC companyfacts...
# [AVGO] summarizing segment descriptions (LLM)...
# [TSLA] selecting segment table (iter 1)...
# [TSLA] inferring layout for t0012 (iter 1)...
# [JPM] selecting segment table (iter 1)...
# [JPM] inferring layout for t0336 (iter 1)...
# [JPM] extracting total revenue from income statement t0117...
# [JPM] income statement total not found; falling back to SEC companyfacts...
# [JPM] selecting segment table (iter 2)...
# [JPM] inferring layout for t0336 (iter 2)...
# [JPM] extracting total revenue from income statement t0117...
# [JPM] income statement total not found; falling back to SEC companyfacts...
# [JPM] selecting segment table (iter 3)...
# [JPM] inferring layout for t0336 (iter 3)...
# [JPM] extracting total revenue from income statement t0117...
# [JPM] income statement total not found; falling back to SEC companyfacts...
# [XOM] selecting segment table (iter 1)...
# [XOM] inferring layout for t0110 (iter 1)...
# [XOM] extracting total revenue from income statement t0170...
# [XOM] income statement total not found; falling back to SEC companyfacts...
# [XOM] selecting segment table (iter 2)...
# [XOM] inferring layout for t0100 (iter 2)...
# [XOM] extracting total revenue from income statement t0170...
# [XOM] income statement total not found; falling back to SEC companyfacts...
# [XOM] selecting segment table (iter 3)...
# [XOM] inferring layout for t0100 (iter 3)...
# [XOM] extracting total revenue from income statement t0170...
# [XOM] income statement total not found; falling back to SEC companyfacts...
# {'AAPL': {'errors': ['LLMError: Failed to parse model JSON output: '
#                      'Unterminated string starting at: line 160 column 42 '
#                      '(char 8403)\n'
#                      'Raw:\n'
#                      '{\n'
#                      '  "rows": [\n'
#                      '    {\n'
#                      '      "segment": "Mac",\n'
#                      '      "business_item": "MacBook Air",\n'
#                      '      "business_item_short_description": "Lightweight '
#                      'laptop with macOS",\n'
#                      '      "business_item_long_description": "A thin and '
#                      'light laptop designed for portability and performance, '
#                      'running macOS, suitable for everyday computing tasks.",\n'
#                      '      "primary_source": "Apple Inc. 2025 Form 10-K"\n'
#                      '    },\n'
#                      '    {\n'
#                      '      "segment": "Mac",\n'
#                      '      "business_item": "MacBook Pro",\n'
#                      '      "business_item_short_description": '
#                      '"High-performance professional laptop",\n'
#                      '      "business_item_long_description": "A powerful '
#                      'laptop designed for professionals and creatives, '
#                      'featuring advanced processors and high-resolution '
#                      'displays, running macOS.",\n'
#                      '      "primary_source": "Apple Inc. 2025 Form 10-K"\n'
#                      '    },\n'
#                      '    {\n'
#                      '      "segment": "Mac",\n'
#                      '      "business_item": "iMac",\n'
#                      '      "business_item_short_description": "All-in-one '
#                      'desktop computer",\n'
#                      '      "business_item_long_description": "A desktop '
#                      'computer integrating the display and computing '
#                      'components in a single unit, designed for home and '
#                      'professional use with macOS.",\n'
#                      '      "primary_source": "Apple Inc. 2025 Form 10-K"\n'
#                      '    },\n'
#                      '    {\n'
#                      '      "segment": "Mac",\n'
#                      '      "business_item": "Mac mini",\n'
#                      '      "business_item_short_description": "Compact '
#                      'desktop computer",\n'
#                      '      "business_item_long_description": "A small '
#                      'form-factor desktop computer offering versatility and '
#                      'performance, running macOS, suitable for various '
#                      'computing needs.",\n'
#                      '      "primary_source": "Apple Inc. 2025 Form 10-K"\n'
#                      '    },\n'
#                      '    {\n'
#                      '      "segment": "Mac",\n'
#                      '      "business_item": "Mac Studio",\n'
#                      '      "business_item_short_description": "High-end '
#                      'desktop for creative professionals",\n'
#                      '      "business_item_long_description": "A powerful '
#                      'desktop computer designed for demanding professional '
#                      'workflows, offering advanced processing and graphics '
#                      'capabilities with macOS.",\n'
#                      '      "primary_source": "Apple Inc. 2025 Form 10-K"\n'
#                      '    },\n'
#                      '    {\n'
#                      '      "segment": "Mac",\n'
#                      '      "business_item": "Mac Pro",\n'
#                      '      "business_item_short_descriptio'],
#           'n_segments': None,
#           'ok': False,
#           'segment_year': None},
#  'AMZN': {'errors': ['LLMError: OpenAI HTTP 429: {\n'
#                      '    "error": {\n'
#                      '        "message": "Rate limit reached for gpt-4.1-mini '
#                      'in organization org-CUB5WJkJXGSYipvL2qmlUeLD on tokens '
#                      'per min (TPM): Limit 60000, Used 45007, Requested 25375. '
#                      'Please try again in 10.382s. Visit '
#                      'https://platform.openai.com/account/rate-limits to learn '
#                      'more. You can increase your rate limit by adding a '
#                      'payment method to your account at '
#                      'https://platform.openai.com/account/billing.",\n'
#                      '        "type": "tokens",\n'
#                      '        "param": null,\n'
#                      '        "code": "rate_limit_exceeded"\n'
#                      '    }\n'
#                      '}\n'],
#           'n_segments': None,
#           'ok': False,
#           'segment_year': None},
#  'AVGO': {'errors': ['LLMError: OpenAI HTTP 429: {\n'
#                      '    "error": {\n'
#                      '        "message": "Rate limit reached for gpt-4.1-mini '
#                      'in organization org-CUB5WJkJXGSYipvL2qmlUeLD on requests '
#                      'per min (RPM): Limit 3, Used 3, Requested 1. Please try '
#                      'again in 20s. Visit '
#                      'https://platform.openai.com/account/rate-limits to learn '
#                      'more. You can increase your rate limit by adding a '
#                      'payment method to your account at '
#                      'https://platform.openai.com/account/billing.",\n'
#                      '        "type": "requests",\n'
#                      '        "param": null,\n'
#                      '        "code": "rate_limit_exceeded"\n'
#                      '    }\n'
#                      '}\n'],
#           'n_segments': None,
#           'ok': False,
#           'segment_year': None},
#  'GOOGL': {'errors': [], 'n_segments': 3, 'ok': True, 'segment_year': 2024},
#  'JPM': {'errors': ['Validation failed after retries; marking ambiguous and '
#                     'skipping CSV outputs for this ticker.'],
#          'n_segments': None,
#          'ok': False,
#          'segment_year': None},
#  'META': {'errors': ['LLMError: OpenAI HTTP 429: {\n'
#                      '    "error": {\n'
#                      '        "message": "Rate limit reached for gpt-4.1-mini '
#                      'in organization org-CUB5WJkJXGSYipvL2qmlUeLD on requests '
#                      'per min (RPM): Limit 3, Used 3, Requested 1. Please try '
#                      'again in 20s. Visit '
#                      'https://platform.openai.com/account/rate-limits to learn '
#                      'more. You can increase your rate limit by adding a '
#                      'payment method to your account at '
#                      'https://platform.openai.com/account/billing.",\n'
#                      '        "type": "requests",\n'
#                      '        "param": null,\n'
#                      '        "code": "rate_limit_exceeded"\n'
#                      '    }\n'
#                      '}\n'],
#           'n_segments': None,
#           'ok': False,
#           'segment_year': None},
#  'MSFT': {'errors': ['LLMError: OpenAI HTTP 429: {\n'
#                      '    "error": {\n'
#                      '        "message": "Rate limit reached for gpt-4.1-mini '
#                      'in organization org-CUB5WJkJXGSYipvL2qmlUeLD on requests '
#                      'per min (RPM): Limit 3, Used 3, Requested 1. Please try '
#                      'again in 20s. Visit '
#                      'https://platform.openai.com/account/rate-limits to learn '
#                      'more. You can increase your rate limit by adding a '
#                      'payment method to your account at '
#                      'https://platform.openai.com/account/billing.",\n'
#                      '        "type": "requests",\n'
#                      '        "param": null,\n'
#                      '        "code": "rate_limit_exceeded"\n'
#                      '    }\n'
#                      '}\n'],
#           'n_segments': None,
#           'ok': False,
#           'segment_year': None},
#  'NVDA': {'errors': ['Failed to extract segment revenues'],
#           'n_segments': None,
#           'ok': False,
#           'segment_year': None},
#  'TSLA': {'errors': ['LLMError: OpenAI HTTP 429: {\n'
#                      '    "error": {\n'
#                      '        "message": "Rate limit reached for gpt-4.1-mini '
#                      'in organization org-CUB5WJkJXGSYipvL2qmlUeLD on requests '
#                      'per min (RPM): Limit 3, Used 3, Requested 1. Please try '
#                      'again in 20s. Visit '
#                      'https://platform.openai.com/account/rate-limits to learn '
#                      'more. You can increase your rate limit by adding a '
#                      'payment method to your account at '
#                      'https://platform.openai.com/account/billing.",\n'
#                      '        "type": "requests",\n'
#                      '        "param": null,\n'
#                      '        "code": "rate_limit_exceeded"\n'
#                      '    }\n'
#                      '}\n'],
#           'n_segments': None,
#           'ok': False,
#           'segment_year': None},
#  'XOM': {'errors': ['Failed to extract segment revenues'],
#          'n_segments': None,
#          'ok': False,
#          'segment_year': None}}
#
# Wrote outputs under: C:\Users\yehud\Business Classification\data\outputs
